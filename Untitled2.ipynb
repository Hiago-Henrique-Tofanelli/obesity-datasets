# %%
import pandas as pd

# %%
obesityDT = pd.read_csv('Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023.csv')
obesityDT
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 2       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 3       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 4       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 620995  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 620996  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 620997  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 620998  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 620999  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State       Condition Group                Condition  \
# 0       United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
# Filtrando o DataFrame para incluir apenas as entradas com 'State' igual a 'United States'
obesityDT_us = obesityDT[obesityDT['State'] == 'United States']

# Agora, 'obesityDT_us' contém apenas as entradas para o estado 'United States'

# %%
obesityDT_us
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 0      09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1      09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 2      09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 3      09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 4      09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 72445  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 72446  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 72447  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 72448  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 72449  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                State       Condition Group                Condition  \
# 0      United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
# Filtrando o DataFrame para incluir apenas as entradas com 'State' igual a 'United States' e 'Condition' igual a 'obesity'
obesityDT_filtered = obesityDT[(obesityDT['State'] == 'United States') & (obesityDT['Condition'] == 'Obesity')]

# Agora, 'obesityDT_filtered' contém apenas as entradas para o estado 'United States' com 'Condition' igual a 'obesity'

# %%
obesityDT_filtered
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 160    09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 161    09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 162    09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 163    09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 164    09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 69745  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 69746  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 69747  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 69748  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 69749  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                State Condition Group Condition ICD10_codes Age Group  \
# 160    United States         Obesity   Obesity     E65-E68      0-24
# ...

# %%
# Removendo as colunas "Year", "Month" e "ICD10_codes" do DataFrame
obesityDT_filtered = obesityDT.drop(columns=['Year', 'Month', 'ICD10_codes'])

# Agora, 'obesityDT_filtered' contém as demais colunas, exceto "Year", "Month" e "ICD10_codes"

# %%
obesityDT_filtered
# Out:
#         Data As Of  Start Date    End Date     Group          State  \
# 0       09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 1       09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 2       09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 3       09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 4       09/24/2023  01/01/2020  09/23/2023  By Total  United States
# ...            ...         ...         ...       ...            ...
# 620995  09/24/2023  05/01/2023  05/31/2023  By Month    Puerto Rico
# 620996  09/24/2023  06/01/2023  06/30/2023  By Month    Puerto Rico
# 620997  09/24/2023  07/01/2023  07/31/2023  By Month    Puerto Rico
# 620998  09/24/2023  08/01/2023  08/31/2023  By Month    Puerto Rico
# 620999  09/24/2023  09/01/2023  09/23/2023  By Month    Puerto Rico
#
#              Condition Group                Condition Age Group  \
# 0       Respiratory diseases  Influenza and pneumonia      0-24
# ...

# %%
obesityDT_filtered = obesityDT_filtered[(obesityDT_filtered['Age Group'] != 'All Ages') & (obesityDT_filtered['Age Group'] != 'Not stated')]

obesityDT_filtered = obesityDT_filtered[(obesityDT_filtered['State'] == 'United States') & (obesityDT_filtered['Condition'] == 'Obesity')]

obesityDT_filtered = obesityDT_filtered[(obesityDT_filtered['Group'] == 'By Total')]

obesityDT_filtered
# Out:
#    Data As Of  Start Date    End Date     Group          State  \
# 1  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 2  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 3  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 4  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 5  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 6  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 7  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 8  09/24/2023  01/01/2020  09/23/2023  By Total  United States
#
#   Condition Group Condition Age Group  COVID-19 Deaths  Number of Mentions  \
# 1         Obesity   Obesity      0-24            707.0               708.0
# 2         Obesity   Obesity     25-34           2865.0              2875.0
# 3         Obesity   Obesity     35-44           5910.0              5936.0
# 4         Obesity   Obesity     45-54           9878.0              9896.0
# ...

# %%
# Substituindo a numeração das linhas pelos valores de 1 a 7
obesityDT_filtered.index = range(1, 9)

obesityDT_filtered
# Out:
#    Data As Of  Start Date    End Date     Group          State  \
# 1  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 2  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 3  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 4  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 5  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 6  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 7  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 8  09/24/2023  01/01/2020  09/23/2023  By Total  United States
#
#   Condition Group Condition Age Group  COVID-19 Deaths  Number of Mentions  \
# 1         Obesity   Obesity      0-24            707.0               708.0
# 2         Obesity   Obesity     25-34           2865.0              2875.0
# 3         Obesity   Obesity     35-44           5910.0              5936.0
# 4         Obesity   Obesity     45-54           9878.0              9896.0
# ...

# %%
# Removendo a coluna "Flag"
# obesityDT_filtered = obesityDT_filtered.drop(columns=['Flag'])

# obesityDT_filtered = obesityDT_filtered.drop(columns=['Number of Mentions'])

obesityDT_filtered = obesityDT_filtered.drop(columns=['Condition'])

obesityDT_filtered
# Out:
#    Data As Of  Start Date    End Date     Group          State  \
# 1  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 2  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 3  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 4  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 5  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 6  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 7  09/24/2023  01/01/2020  09/23/2023  By Total  United States
# 8  09/24/2023  01/01/2020  09/23/2023  By Total  United States
#
#   Condition Group Age Group  COVID-19 Deaths
# 1         Obesity      0-24            707.0
# 2         Obesity     25-34           2865.0
# 3         Obesity     35-44           5910.0
# 4         Obesity     45-54           9878.0
# 5         Obesity     55-64          13715.0
# 6         Obesity     65-74          12516.0
# 7         Obesity     75-84           6208.0
# ...

# %%
# Calculando a soma do número de mortos na coluna "COVID-19 Deaths"
soma_mortos = obesityDT_filtered['COVID-19 Deaths'].sum()

# Exibindo o resultado da soma
print(f'O número total de mortos é: {soma_mortos}')
# Out:
# O número total de mortos é: 53319.0

# %%
import matplotlib.pyplot as plt

# Dados do DataFrame (você pode usar seus próprios dados)
idades = ['0-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '85+']
mortes = [707, 2865, 5910, 9878, 13715, 12516, 6208, 1520]

# Criar um gráfico de barras relacionando idades com o número de mortes
plt.figure(figsize=(10, 6))
plt.bar(idades, mortes, color='skyblue')
plt.xlabel('Idade')
plt.ylabel('Número de Mortes')
plt.title('Número de Mortes por Idade')
plt.xticks(rotation=45)

# Exibir o gráfico
plt.show()
